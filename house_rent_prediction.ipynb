# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

import warnings
warnings.filterwarnings('ignore')

# %%
hyd_rent_df = pd.read_csv('data/Hyd_house_rent_data.csv')
hyd_rent_df.head()
# Out:
#    active                                          amenities balconies  \
# 0    True  {"LIFT":true,"GYM":false,"INTERNET":false,"AC"...         3
# 1    True  {"LIFT":false,"GYM":false,"INTERNET":false,"AC...         1
# 2    True  {"LIFT":true,"GYM":true,"INTERNET":false,"AC":...         3
# 3    True  {"LIFT":false,"GYM":false,"INTERNET":false,"AC...         1
# 4    True  {"LIFT":true,"GYM":false,"INTERNET":false,"AC"...         2
#
#    bathroom  combineDescription  \
# 0         3                 NaN
# 1         2                 NaN
# 2         3                 NaN
# 3         2                 NaN
# 4         2                 NaN
#
#                                   completeStreetName  deposit facing  \
# 0  Shreya carnation, Block I, NCB Enclave, Gachib...    90000      W
# 1     Inner Ring Rd,  near RTO Bandlaguda South Zone    45000      E
# 2  Rd Number 2, Shirdi Sai Nagar, Manikonda, Hyde...    80000      E
# 3  Plot No. 44, Road No. 1/A, kakatiya colony, LB...    18000      W
# 4  Madhapur HUDA Techno Enclave,  Near MaxCure Su...    80000      E
#
#   facingDesc  floor  ... property_size  reactivationSource rent_amount  \
# 0       West      3  ...          2200      USER_DASHBOARD       28000
# 1       East      2  ...          1200      USER_DASHBOARD       15000
# 2       East      0  ...          1800         MISSED_CALL       16000
# 3       West      2  ...           750         MISSED_CALL        9000
# 4       East      2  ...          1250                None       32500
#
#    sharedAccomodation                 shortUrl  swimmingPool totalFloor  \
# 0               False  http://nobr.kr/sv/9Kvqj         False          5
# 1               False  http://nobr.kr/sv/j2pD6         False          2
# 2               False  http://nobr.kr/sv/TXJmj         False          3
# 3               False  http://nobr.kr/sv/FnCsf         False          2
# 4               False  http://nobr.kr/sv/BQFRb         False          5
#
#   type_bhk waterSupply weight
# 0     BHK3   CORP_BORE    NaN
# 1     BHK3    BOREWELL    NaN
# 2     BHK3   CORP_BORE    NaN
# 3     BHK2   CORP_BORE    NaN
# 4     BHK2   CORP_BORE    NaN
#
# [5 rows x 36 columns]

# %%
hyd_rent_df.columns
# Out:
# Index(['active', 'amenities', 'balconies', 'bathroom', 'combineDescription',
#        'completeStreetName', 'deposit', 'facing', 'facingDesc', 'floor',
#        'furnishingDesc', 'gym', 'id', 'isMaintenance', 'lift', 'loanAvailable',
#        'locality', 'localityId', 'location', 'maintenanceAmount', 'ownerName',
#        'parking', 'parkingDesc', 'propertyTitle', 'propertyType',
#        'property_age', 'property_size', 'reactivationSource', 'rent_amount',
#        'sharedAccomodation', 'shortUrl', 'swimmingPool', 'totalFloor',
#        'type_bhk', 'waterSupply', 'weight'],
#       dtype='object')

# %%
df= hyd_rent_df[['localityId','type_bhk','balconies', 'bathroom','parking', 'lift','furnishingDesc','maintenanceAmount',
                      'property_size','rent_amount']]
df.head()
# Out:
#                   localityId type_bhk balconies  bathroom      parking   lift  \
# 0       gachibowli_hyderabad     BHK3         3         3         BOTH   True
# 1  chandrayangutta_hyderabad     BHK3         1         2  TWO_WHEELER  False
# 2        manikonda_hyderabad     BHK3         3         3         BOTH   True
# 3                  NOT_FOUND     BHK2         1         2         BOTH  False
# 4      hitech_city_hyderabad     BHK2         2         2         BOTH   True
#
#   furnishingDesc maintenanceAmount  property_size  rent_amount
# 0           Semi              2000           2200        28000
# 1    Unfurnished              None           1200        15000
# 2           Semi              1000           1800        16000
# 3    Unfurnished               500            750         9000
# 4           Semi              2000           1250        32500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19110 entries, 0 to 19109
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   localityId         19110 non-null  object
#  1   type_bhk           19110 non-null  object
#  2   balconies          19110 non-null  object
#  3   bathroom           19110 non-null  int64
#  4   parking            19110 non-null  object
#  5   lift               19110 non-null  bool
#  6   furnishingDesc     19110 non-null  object
#  7   maintenanceAmount  19110 non-null  object
#  8   property_size      19110 non-null  int64
#  9   rent_amount        19110 non-null  int64
# dtypes: bool(1), int64(3), object(6)
# memory usage: 1.3+ MB

# %%
df.localityId.unique()
# Out:
# array(['gachibowli_hyderabad', 'chandrayangutta_hyderabad',
#        'manikonda_hyderabad', 'NOT_FOUND', 'hitech_city_hyderabad',
#        'serilingampally_hyderabad', 'nanakram_guda_hyderabad',
#        'toli_chowki_hyderabad', 'yousufguda_hyderabad',
#        'mehdipatnam_hyderabad', 'kondapur_hyderabad',
#        'kukatpally_hyderabad', 'hafeezpet_hyderabad',
#        'new_malakpet_hyderabad', 'banjara_hills_hyderabad',
#        'himayath_nagar_hyderabad', 'upparpally_hyderabad',
#        'shaikpet_hyderabad', 'mettakanigudem_hyderabad',
#        'dammaiguda_hyderabad', 'kokapet_hyderabad', 'attapur_hyderabad',
#        'west_marredpally_hyderabad', 'miyapur_hyderabad',
#        'shilpa_hills_hyderabad', 'qutub_shahi_tombs_hyderabad',
#        'kothaguda_hyderabad', 'somajiguda_hyderabad',
#        'madhapur_hyderabad', 'gopanapalli_thanda_hyderabad',
#        'chintalakunta_hyderabad',
#        'bharat_heavy_electricals_limited_hyderabad',
#        'peeramcheru_hyderabad', 'narsingi_hyderabad',
#        'zamistanpur_hyderabad', 'manchirevula_hyderabad',
#        'uppal_hyderabad', 'rhoda_mistri_nagar_hyderabad',
#        'old_malakpet_hyderabad', 'amberpet_hyderabad', 'nagole_hyderabad',
#        'east_nehru_nagar_hyderabad', 'nallagandla_hyderabad',
#        'begumpet_hyderabad', 'mahadevpur_colony_hyderabad',
#        'rai_durg_hyderabad', 'ramachandra_puram_hyderabad',
#        'adikmet_hyderabad', 'ibrahim_bagh_hyderabad',
#        'nacharam_hyderabad', 'jillelguda_hyderabad', 'bolarum_hyderabad',
#        'puppalaguda_hyderabad', 'chinthal_basthi_hyderabad',
#        'punjagutta_hyderabad', 'sanjeeva_reddy_nagar_hyderabad',
#        'kachiguda_hyderabad', 'nizampet_hyderabad',
#        'sanath_nagar_hyderabad', 'east_marredpally_hyderabad',
#        'trimalgherry_hyderabad', 'kismatpur_hyderabad',
#        'pragathi_nagar_hyderabad', 'meerpet_hyderabad',
#        'neredmet_hyderabad', 'masab_tank_hyderabad',
#        'saroornagar_hyderabad', 'hakimpet_hyderabad',
#        'basheer_bagh_hyderabad', 'chilakalguda_hyderabad',
#        'nallakunta_hyderabad', 'badangpet_hyderabad',
#        'balanagar_hyderabad', 'kapra_hyderabad', 'gopanapalli_hyderabad',
#        'adarsh_nagar_hyderabad', 'padmarao_nagar_hyderabad',
#        'kavadiguda_hyderabad', 'rambagh_colony_hyderabad',
#        'patancheru_hyderabad', 'badesahebguda_hyderabad',
#        'jubilee_hills_hyderabad', 'ramgopalpet_hyderabad',
#        'kothapet_hyderabad', 'moula_ali_hyderabad', 'tellapur_hyderabad',
#        'sainikpuri_hyderabad', 'old_bowenpally_hyderabad',
#        'khairatabad_hyderabad', 'habsiguda_hyderabad',
#        'boduppal_hyderabad', 'budvel_hyderabad',
#        'jagadgiri_gutta_hyderabad', 'appa_junction_hyderabad',
#        'bhoiguda_hyderabad', 'janachaitanya_colony_hyderabad',
#        'gandipet_hyderabad', 'hyder_nagar_hyderabad', 'kollur_hyderabad',
#        'seethariguda_hyderabad', 'rudra_colony_hyderabad',
#        'kamalaprasad_nagar_hyderabad', 'tarnaka_hyderabad',
#        'hayathnagar_hyderabad', 'quthbullapur_hyderabad',
#        'gaddi_annaram_hyderabad', 'peerzadiguda_hyderabad',
#        'borabanda_hyderabad', 'ameerpet_hyderabad',
#        'vijaya_nagar_colony_hyderabad', 'kistareddypet_hyderabad',
#        'santosh_nagar_hyderabad', 'dullapally_hyderabad',
#        'hmt_officers_colony_hyderabad', 'moosapet_hyderabad',
#        'gundlapochampalli_hyderabad', 'jeedimetla_hyderabad',
#        'yapral_hyderabad', 'suraram_hyderabad', 'erragadda_hyderabad',
#        'mallampet_hyderabad', 'gandiguda_hyderabad',
#        'golconda_fort_hyderabad', 'cherlapalli_hyderabad',
#        'turkayamjal_hyderabad', 'almasguda_hyderabad',
#        'yella_reddy_guda_hyderabad', 'munganoor_hyderabad',
#        'whisper_valley_hyderabad', 'chengicherla_hyderabad',
#        'krishna_reddy_pet_hyderabad', 'bongloor_hyderabad',
#        'khaja_guda_hyderabad', 'gudimalkapur_hyderabad',
#        'lb_nagar_hyderabad', 'hastinapuram_hyderabad',
#        'darga_khaliz_khan_hyderabad', 'sivarampalli_hyderabad',
#        'kandla_koya_hyderabad', 'osman_nagar_hyderabad',
#        'sri_nagar_colony_hyderabad', 'ismailkhanguda_hyderabad',
#        'kundanpally_hyderabad', 'koti_hyderabad', 'beeramguda_hyderabad',
#        'safilguda_hyderabad', 'humayun_nagar_hyderabad',
#        'nagaram_hyderabad', 'lakdikapul_hyderabad',
#        'kalasiguda_hyderabad', 'auto_nagar_hyderabad',
#        'jawahar_nagar_hyderabad', 'mansoorabad_hyderabad',
#        'pedda_amberpet_hyderabad', 'balaji_nagar_hyderabad',
#        'devatabowli_hyderabad', 'nawab_saheb_kunta_hyderabad',
#        'neeladri_nagar_hyderabad', 'gowlidody_hyderabad',
#        'redhills_hyderabad', 'bowrampet_hyderabad',
#        'annojiguda_hyderabad', 'bairagiguda_hyderabad',
#        'telephone_colony_hyderabad', 'karmanghat_hyderabad',
#        'bahadurpura_hyderabad', 'kushaiguda_hyderabad',
#        'kowkur_hyderabad', 'gajularamaram_hyderabad',
#        'rampally_hyderabad', 'malakpet_hyderabad', 'patelguda_hyderabad',
#        'quli_qutub_shah_nagar_colony_hyderabad', 'bollaram_hyderabad',
#        'rasoolpura_hyderabad', 'siddanthi_hyderabad',
#        'boudhanagar_colony_hyderabad', 'godumakunta_hyderabad',
#        'dawoodkhanguda_hyderabad', 'kaiser_nagar_hyderabad',
#        'chinthal_hyderabad', 'buddha_nagar_hyderabad',
#        'yakutpura_hyderabad', 'balakampet_hyderabad',
#        'narapally_hyderabad', 'karkhana_hyderabad',
#        'komaram_bheem_colony_hyderabad', 'new_mallepally_hyderabad',
#        'gunrock_enclave_hyderabad', 'narayanguda_hyderabad',
#        'balapur_hyderabad', 'ida_mallapur_hyderabad',
#        'chintalmet_hyderabad', 'asif_nagar_hyderabad',
#        'syed_ali_guda_hyderabad', 'ramanthapur_hyderabad',
#        'langar_houz_hyderabad', 'tukaram_gate_hyderabad',
#        'darulshifa_hyderabad', 'nampally_hyderabad', 'khanapur_hyderabad',
#        'thumukunta_hyderabad', 'medchal_hyderabad',
#        'rakshapuram_hyderabad', 'rajendra_nagar_hyderabad',
#        'hari_bowli_hyderabad', 'moosarambagh_hyderabad',
#        'asif_nagar_north_hyderabad', 'ragannaguda_hyderabad',
#        'saraswathi_nagar_colony_hyderabad', 'east_bahadurpura_hyderabad',
#        'abids_hyderabad', 'bahadurpura_west_hyderabad',
#        'nadergul_hyderabad', 'kanchan_bagh_hyderabad',
#        'electronic_city_bangalore', 'venkusa_estates_hyderabad',
#        'ambedkar_nagar_hyderabad', 'jam_bagh_hyderabad',
#        'maharaja_ranjeet_singh_nagar_hyderabad', 'rani_gunj_hyderabad',
#        'chowdhariguda_hyderabad', 'gurram_guda_hyderabad',
#        'bahadurpally_hyderabad', 'chudi_bazaar_hyderabad',
#        'gowliguda_hyderabad', 'pashambanda_hyderabad',
#        'azamabad_hyderabad', 'kuntloor_hyderabad',
#        'aeronagar_hal_employees_colony_hyderabad',
#        'bollaram_industrial_area_hyderabad',
#        'venkat_nagar_colony_hyderabad', 'aliabad_hyderabad',
#        'ulsoor_bangalore', 'hafiz_baba_nagar_hyderabad',
#        'vattepally_hyderabad', 'manneguda_hyderabad',
#        'mangal_hat_east_hyderabad', 'chanchalguda_hyderabad',
#        'ammasani_venkatreddy_colony_hyderabad',
#        'gandi_maisamma_hyderabad', 'katedan_industrial_area_hyderabad',
#        'happy_homes_colony_hyderabad', 'premavathi_pet_hyderabad',
#        'raji_reddy_nagar_hyderabad', 'nandi_musalai_guda_hyderabad',
#        'dabeerpura_hyderabad', 'bhadurpalle_hyderabad',
#        'samshabad_colony_hyderabad', 'laxmiguda_hyderabad',
#        'srinilaya_township_hyderabad', 'tuljaram_nagar_hyderabad',
#        'asmangadh_hyderabad', 'fort_mumbai',
#        'laxma_reddy_nagar_hyderabad', 'pardhi_guda_hyderabad',
#        'anand_nagar_hyderabad', 'r_krishnaiah_nagar_hyderabad',
#        'shah_gunj_hyderabad', 'tatianaram_hyderabad',
#        'shalibanda_hyderabad', 'ramnas_pura_hyderabad',
#        'karwan_east_hyderabad', 'ootpally_hyderabad',
#        'aditya_bank_colony_hyderabad', 'sri_shakti_nagar_hyderabad',
#        'majeedpur_hyderabad', 'badshahpet_hyderabad',
#        'jalapalli_hyderabad'], dtype=object)

# %%
df.type_bhk.value_counts()
# Out:
# BHK2        9242
# BHK3        4229
# BHK1        4221
# RK1         1149
# BHK4         211
# BHK4PLUS      58
# Name: type_bhk, dtype: int64

# %%
df.isnull().sum()
# Out:
# localityId           0
# type_bhk             0
# balconies            0
# bathroom             0
# parking              0
# lift                 0
# furnishingDesc       0
# maintenanceAmount    0
# property_size        0
# rent_amount          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
print(df.bathroom.unique())
print(df.balconies.unique())
print(df.parking.unique())
print(df.furnishingDesc.unique())
# Out:
# [ 3  2  1  4  5  7  6  8 12 14]
# ['3' '1' '2' '0' 'None' '4' '5' '120' '12' '6' '110']
# ['BOTH' 'TWO_WHEELER' 'FOUR_WHEELER' 'NONE']
# ['Semi' 'Unfurnished' 'Full']

# %%
df.replace({'parking':{'NONE':0,'TWO_WHEELER':1,'FOUR_WHEELER':2,'BOTH':3}},inplace=True)
df.replace({'lift':{'False':0,'True':1}},inplace=True)
df.replace({'furnishingDesc':{'Unfurnished':0,'Semi':0.5,'Full':1}},inplace=True)
df.replace({'type_bhk':{'RK1':0.5,'BHK1':1,'BHK2':2,'BHK3':3,'BHK4':4,'BHK4PLUS':5}},inplace=True)
df.replace({'maintenanceAmount':{'None':int(0)}},inplace=True)

# %%
df.head()
# Out:
#                   localityId  type_bhk balconies  bathroom  parking   lift  \
# 0       gachibowli_hyderabad       3.0         3         3        3   True
# 1  chandrayangutta_hyderabad       3.0         1         2        1  False
# 2        manikonda_hyderabad       3.0         3         3        3   True
# 3                  NOT_FOUND       2.0         1         2        3  False
# 4      hitech_city_hyderabad       2.0         2         2        3   True
#
#    furnishingDesc maintenanceAmount  property_size  rent_amount
# 0             0.5              2000           2200        28000
# 1             0.0                 0           1200        15000
# 2             0.5              1000           1800        16000
# 3             0.0               500            750         9000
# 4             0.5              2000           1250        32500

# %%
df.lift= df.lift.apply(lambda x: 1 if x is True else 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19110 entries, 0 to 19109
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   localityId         19110 non-null  object
#  1   type_bhk           19110 non-null  float64
#  2   balconies          19110 non-null  object
#  3   bathroom           19110 non-null  int64
#  4   parking            19110 non-null  int64
#  5   lift               19110 non-null  int64
#  6   furnishingDesc     19110 non-null  float64
#  7   maintenanceAmount  19110 non-null  object
#  8   property_size      19110 non-null  int64
#  9   rent_amount        19110 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 1.5+ MB

# %%
df.replace({'balconies':{'None':int(0)}},inplace=True)
df['balconies'] = df['balconies'].apply(lambda x:int(x))
df['maintenance']=df['maintenanceAmount'].apply(lambda x:int(x))
df.drop(['maintenanceAmount'],axis=1,inplace= True)

# %%
df.head()
# Out:
#                   localityId  type_bhk  balconies  bathroom  parking  lift  \
# 0       gachibowli_hyderabad       3.0          3         3        3     1
# 1  chandrayangutta_hyderabad       3.0          1         2        1     0
# 2        manikonda_hyderabad       3.0          3         3        3     1
# 3                  NOT_FOUND       2.0          1         2        3     0
# 4      hitech_city_hyderabad       2.0          2         2        3     1
#
#    furnishingDesc  property_size  rent_amount  maintenance
# 0             0.5           2200        28000         2000
# 1             0.0           1200        15000            0
# 2             0.5           1800        16000         1000
# 3             0.0            750         9000          500
# 4             0.5           1250        32500         2000

# %%
df.describe()
# Out:
#            type_bhk     balconies      bathroom       parking          lift  \
# count  19110.000000  19110.000000  19110.000000  19110.000000  19110.000000
# mean       1.941418      0.742491      1.911826      2.014076      0.319990
# std        0.803456      1.682343      0.764841      1.043941      0.466484
# min        0.500000      0.000000      1.000000      0.000000      0.000000
# 25%        1.000000      0.000000      1.000000      1.000000      0.000000
# 50%        2.000000      0.000000      2.000000      3.000000      0.000000
# 75%        2.000000      1.000000      2.000000      3.000000      1.000000
# max        5.000000    120.000000     14.000000      3.000000      1.000000
#
#        furnishingDesc  property_size    rent_amount   maintenance
# count    19110.000000   19110.000000   19110.000000  19110.000000
# mean         0.307718    1067.674411   14919.719362    809.927682
# std          0.315218     549.019152    9623.547307   1345.363049
# min          0.000000       0.000000       0.000000     -2.000000
# 25%          0.000000     700.000000    8999.000000      0.000000
# 50%          0.500000    1000.000000   12500.000000      0.000000
# 75%          0.500000    1334.000000   18000.000000   1300.000000
# max          1.000000   12000.000000  100000.000000  32000.000000

# %%
locality_stats=df.groupby('localityId')['localityId'].count().sort_values(ascending=False)
locality_stats
# Out:
# localityId
# NOT_FOUND                                 3491
# kondapur_hyderabad                        1338
# kukatpally_hyderabad                      1146
# miyapur_hyderabad                          721
# hafeezpet_hyderabad                        663
#                                           ...
# maharaja_ranjeet_singh_nagar_hyderabad       1
# majeedpur_hyderabad                          1
# chanchalguda_hyderabad                       1
# east_bahadurpura_hyderabad                   1
# asmangadh_hyderabad                          1
# Name: localityId, Length: 269, dtype: int64

# %%
loc_less_than_10= locality_stats[locality_stats<=10]
loc_less_than_10
# Out:
# localityId
# bairagiguda_hyderabad                     10
# nampally_hyderabad                        10
# kanchan_bagh_hyderabad                    10
# koti_hyderabad                            10
# auto_nagar_hyderabad                      10
#                                           ..
# maharaja_ranjeet_singh_nagar_hyderabad     1
# majeedpur_hyderabad                        1
# chanchalguda_hyderabad                     1
# east_bahadurpura_hyderabad                 1
# asmangadh_hyderabad                        1
# Name: localityId, Length: 119, dtype: int64

# %%
df['localityId']= df['localityId'].apply(lambda x: 'Not_Found' if x in loc_less_than_10 else x)
df.localityId.value_counts()
# Out:
# NOT_FOUND                     3491
# kondapur_hyderabad            1338
# kukatpally_hyderabad          1146
# miyapur_hyderabad              721
# hafeezpet_hyderabad            663
#                               ...
# sri_nagar_colony_hyderabad      11
# tukaram_gate_hyderabad          11
# gurram_guda_hyderabad           11
# kuntloor_hyderabad              11
# buddha_nagar_hyderabad          11
# Name: localityId, Length: 151, dtype: int64

# %%
df['localityId'] = df['localityId'].replace('Not_Found','NOT_FOUND')

# %% [markdown]
# ## Feature Engineering

# %%
df['rent_per_sqft'] = df['rent_amount'] /df['property_size']
df
# Out:
#                     localityId  type_bhk  balconies  bathroom  parking  lift  \
# 0         gachibowli_hyderabad       3.0          3         3        3     1
# 1                    NOT_FOUND       3.0          1         2        1     0
# 2          manikonda_hyderabad       3.0          3         3        3     1
# 3                    NOT_FOUND       2.0          1         2        3     0
# 4        hitech_city_hyderabad       2.0          2         2        3     1
# ...                        ...       ...        ...       ...      ...   ...
# 19105       rai_durg_hyderabad       1.0          0         1        3     1
# 19106                NOT_FOUND       2.0          2         2        3     0
# 19107       moosapet_hyderabad       2.0          0         3        3     0
# 19108                NOT_FOUND       1.0          0         1        1     0
# 19109  santosh_nagar_hyderabad       1.0          0         1        1     0
#
#        furnishingDesc  property_size  rent_amount  maintenance  rent_per_sqft
# 0                 0.5           2200        28000         2000      12.727273
# 1                 0.0           1200        15000            0      12.500000
# 2                 0.5           1800        16000         1000       8.888889
# 3                 0.0            750         9000          500      12.000000
# 4                 0.5           1250        32500         2000      26.000000
# ...               ...            ...          ...          ...            ...
# 19105             0.0            500         8500          500      17.000000
# 19106             0.0            900         8500          500       9.444444
# 19107             0.0           1150        15000            0      13.043478
# 19108             0.0            500         7000            0      14.000000
# 19109             0.0            400         5500            0      13.750000
#
# [19110 rows x 11 columns]

# %%
def remove_rps_outliers(df):
    df_out = pd.DataFrame()
    for key,subdf in df.groupby('localityId'):
        m=np.mean(subdf.rent_per_sqft)
        st=np.std(subdf.rent_per_sqft) 
        reduced_df=subdf[(subdf.rent_per_sqft>(m-st))&(subdf.rent_per_sqft<=(m+st))]
        df_out=pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out

# %%
df1= remove_rps_outliers(df)
df1.shape
# Out:
# (10394, 11)

# %%
df2= df1[df1['balconies']<12]
df2
# Out:
#                   localityId  type_bhk  balconies  bathroom  parking  lift  \
# 0          adikmet_hyderabad       2.0          1         2        1     0
# 1          adikmet_hyderabad       3.0          2         3        3     1
# 2          adikmet_hyderabad       2.0          1         2        1     0
# 3          adikmet_hyderabad       2.0          1         2        1     0
# 4          adikmet_hyderabad       2.0          2         1        1     0
# ...                      ...       ...        ...       ...      ...   ...
# 10389  zamistanpur_hyderabad       2.0          2         2        3     1
# 10390  zamistanpur_hyderabad       2.0          0         1        3     0
# 10391  zamistanpur_hyderabad       1.0          0         1        3     0
# 10392  zamistanpur_hyderabad       2.0          2         2        1     0
# 10393  zamistanpur_hyderabad       0.5          0         1        1     0
#
#        furnishingDesc  property_size  rent_amount  maintenance  rent_per_sqft
# 0                 0.0            900        10000            0      11.111111
# 1                 0.5           1780        30000         3560      16.853933
# 2                 0.0            680        10000            0      14.705882
# 3                 0.5           1050        12000         1200      11.428571
# 4                 0.0            600         9500            0      15.833333
# ...               ...            ...          ...          ...            ...
# 10389             0.0           1000        12000         1000      12.000000
# 10390             0.0            720         9000            0      12.500000
# 10391             0.0            500         6000            0      12.000000
# 10392             0.5           1010        16000         1000      15.841584
# 10393             0.0            150         2600            0      17.333333
#
# [10391 rows x 11 columns]

# %%
df3=df2[df2['bathroom']<= df2.type_bhk+1]
df3
# Out:
#                   localityId  type_bhk  balconies  bathroom  parking  lift  \
# 0          adikmet_hyderabad       2.0          1         2        1     0
# 1          adikmet_hyderabad       3.0          2         3        3     1
# 2          adikmet_hyderabad       2.0          1         2        1     0
# 3          adikmet_hyderabad       2.0          1         2        1     0
# 4          adikmet_hyderabad       2.0          2         1        1     0
# ...                      ...       ...        ...       ...      ...   ...
# 10389  zamistanpur_hyderabad       2.0          2         2        3     1
# 10390  zamistanpur_hyderabad       2.0          0         1        3     0
# 10391  zamistanpur_hyderabad       1.0          0         1        3     0
# 10392  zamistanpur_hyderabad       2.0          2         2        1     0
# 10393  zamistanpur_hyderabad       0.5          0         1        1     0
#
#        furnishingDesc  property_size  rent_amount  maintenance  rent_per_sqft
# 0                 0.0            900        10000            0      11.111111
# 1                 0.5           1780        30000         3560      16.853933
# 2                 0.0            680        10000            0      14.705882
# 3                 0.5           1050        12000         1200      11.428571
# 4                 0.0            600         9500            0      15.833333
# ...               ...            ...          ...          ...            ...
# 10389             0.0           1000        12000         1000      12.000000
# 10390             0.0            720         9000            0      12.500000
# 10391             0.0            500         6000            0      12.000000
# 10392             0.5           1010        16000         1000      15.841584
# 10393             0.0            150         2600            0      17.333333
#
# [10364 rows x 11 columns]

# %%
df4= df3[df3['property_size']>300]
df4
# Out:
#                   localityId  type_bhk  balconies  bathroom  parking  lift  \
# 0          adikmet_hyderabad       2.0          1         2        1     0
# 1          adikmet_hyderabad       3.0          2         3        3     1
# 2          adikmet_hyderabad       2.0          1         2        1     0
# 3          adikmet_hyderabad       2.0          1         2        1     0
# 4          adikmet_hyderabad       2.0          2         1        1     0
# ...                      ...       ...        ...       ...      ...   ...
# 10388  zamistanpur_hyderabad       1.0          2         2        3     0
# 10389  zamistanpur_hyderabad       2.0          2         2        3     1
# 10390  zamistanpur_hyderabad       2.0          0         1        3     0
# 10391  zamistanpur_hyderabad       1.0          0         1        3     0
# 10392  zamistanpur_hyderabad       2.0          2         2        1     0
#
#        furnishingDesc  property_size  rent_amount  maintenance  rent_per_sqft
# 0                 0.0            900        10000            0      11.111111
# 1                 0.5           1780        30000         3560      16.853933
# 2                 0.0            680        10000            0      14.705882
# 3                 0.5           1050        12000         1200      11.428571
# 4                 0.0            600         9500            0      15.833333
# ...               ...            ...          ...          ...            ...
# 10388             0.0            500         8000            0      16.000000
# 10389             0.0           1000        12000         1000      12.000000
# 10390             0.0            720         9000            0      12.500000
# 10391             0.0            500         6000            0      12.000000
# 10392             0.5           1010        16000         1000      15.841584
#
# [10117 rows x 11 columns]

# %%
df5 = df4[(df4['maintenance'] >= 0.0) & (df4['maintenance'] <= 0.1 * df4['rent_amount'])]
df5
# Out:
#                   localityId  type_bhk  balconies  bathroom  parking  lift  \
# 0          adikmet_hyderabad       2.0          1         2        1     0
# 2          adikmet_hyderabad       2.0          1         2        1     0
# 3          adikmet_hyderabad       2.0          1         2        1     0
# 4          adikmet_hyderabad       2.0          2         1        1     0
# 5          adikmet_hyderabad       2.0          2         2        3     0
# ...                      ...       ...        ...       ...      ...   ...
# 10388  zamistanpur_hyderabad       1.0          2         2        3     0
# 10389  zamistanpur_hyderabad       2.0          2         2        3     1
# 10390  zamistanpur_hyderabad       2.0          0         1        3     0
# 10391  zamistanpur_hyderabad       1.0          0         1        3     0
# 10392  zamistanpur_hyderabad       2.0          2         2        1     0
#
#        furnishingDesc  property_size  rent_amount  maintenance  rent_per_sqft
# 0                 0.0            900        10000            0      11.111111
# 2                 0.0            680        10000            0      14.705882
# 3                 0.5           1050        12000         1200      11.428571
# 4                 0.0            600         9500            0      15.833333
# 5                 0.5           1000        13000         1000      13.000000
# ...               ...            ...          ...          ...            ...
# 10388             0.0            500         8000            0      16.000000
# 10389             0.0           1000        12000         1000      12.000000
# 10390             0.0            720         9000            0      12.500000
# 10391             0.0            500         6000            0      12.000000
# 10392             0.5           1010        16000         1000      15.841584
#
# [8540 rows x 11 columns]

# %%
df6= df5[df5['localityId'] != 'NOT_FOUND'  ]
df6
# Out:
#                   localityId  type_bhk  balconies  bathroom  parking  lift  \
# 0          adikmet_hyderabad       2.0          1         2        1     0
# 2          adikmet_hyderabad       2.0          1         2        1     0
# 3          adikmet_hyderabad       2.0          1         2        1     0
# 4          adikmet_hyderabad       2.0          2         1        1     0
# 5          adikmet_hyderabad       2.0          2         2        3     0
# ...                      ...       ...        ...       ...      ...   ...
# 10388  zamistanpur_hyderabad       1.0          2         2        3     0
# 10389  zamistanpur_hyderabad       2.0          2         2        3     1
# 10390  zamistanpur_hyderabad       2.0          0         1        3     0
# 10391  zamistanpur_hyderabad       1.0          0         1        3     0
# 10392  zamistanpur_hyderabad       2.0          2         2        1     0
#
#        furnishingDesc  property_size  rent_amount  maintenance  rent_per_sqft
# 0                 0.0            900        10000            0      11.111111
# 2                 0.0            680        10000            0      14.705882
# 3                 0.5           1050        12000         1200      11.428571
# 4                 0.0            600         9500            0      15.833333
# 5                 0.5           1000        13000         1000      13.000000
# ...               ...            ...          ...          ...            ...
# 10388             0.0            500         8000            0      16.000000
# 10389             0.0           1000        12000         1000      12.000000
# 10390             0.0            720         9000            0      12.500000
# 10391             0.0            500         6000            0      12.000000
# 10392             0.5           1010        16000         1000      15.841584
#
# [8540 rows x 11 columns]

# %%
df6.describe()
# Out:
#           type_bhk    balconies     bathroom      parking         lift  \
# count  8540.000000  8540.000000  8540.000000  8540.000000  8540.000000
# mean      1.942037     0.697775     1.881967     1.938525     0.267564
# std       0.724353     0.915505     0.688437     1.045556     0.442715
# min       0.500000     0.000000     1.000000     0.000000     0.000000
# 25%       1.000000     0.000000     1.000000     1.000000     0.000000
# 50%       2.000000     0.000000     2.000000     2.000000     0.000000
# 75%       2.000000     1.000000     2.000000     3.000000     1.000000
# max       5.000000     5.000000     6.000000     3.000000     1.000000
#
#        furnishingDesc  property_size   rent_amount  maintenance  rent_per_sqft
# count     8540.000000    8540.000000    8540.00000  8540.000000    8540.000000
# mean         0.283724    1048.195550   14195.38911   488.584543      13.616811
# std          0.305326     459.224519    8172.39062   734.008272       4.035462
# min          0.000000     310.000000    2500.00000     0.000000       3.250000
# 25%          0.000000     700.000000    9000.00000     0.000000      10.833333
# 50%          0.500000    1000.000000   12000.00000     0.000000      13.125000
# 75%          0.500000    1250.000000   17000.00000  1000.000000      16.000000
# max          1.000000    7000.000000  100000.00000  8500.000000      40.000000

# %%
def plot_scatter_chart(df,localityId):
    bhk1= df[(df.localityId== localityId) & df.type_bhk==1.0]
    bhk2= df[(df.localityId== localityId) & df.type_bhk==2.0]    
    bhk3= df[(df.localityId== localityId) & df.type_bhk==3.0]    
    #bhk4= df[(df.localityId== location) & df.type_bhk==4]
    
    plt.scatter(bhk1.property_size,bhk1.rent_amount,color='red',label='1BHK')
    plt.scatter(bhk2.property_size,bhk2.rent_amount,marker='+',color='blue',label='2BHK')    
    plt.scatter(bhk3.property_size,bhk3.rent_amount,marker='^',color='green',label='3BHK')    
    #plt.scatter(bhk4.property_size,bhk4.rent_amount,marker='*',color='yellow',label='4BHK')   
    plt.xlabel('property_size')
    plt.ylabel('rent_amount')
    
    plt.legend()

plot_scatter_chart(df6,'zamistanpur_hyderabad')

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for locality, locality_df in df.groupby('localityId'):
        bhk_stats = {}
        for bhk, bhk_df in locality_df.groupby('type_bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.rent_per_sqft),
                'std': np.std(bhk_df.rent_per_sqft),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in locality_df.groupby('type_bhk'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.rent_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')

df7 = remove_bhk_outliers(df6)
df7
# Out:
#                   localityId  type_bhk  balconies  bathroom  parking  lift  \
# 2          adikmet_hyderabad       2.0          1         2        1     0
# 4          adikmet_hyderabad       2.0          2         1        1     0
# 6          adikmet_hyderabad       1.0          0         1        0     0
# 9          adikmet_hyderabad       0.5          1         1        3     0
# 11         adikmet_hyderabad       2.0          0         1        1     0
# ...                      ...       ...        ...       ...      ...   ...
# 10384  zamistanpur_hyderabad       1.0          1         1        1     0
# 10387  zamistanpur_hyderabad       2.0          1         1        1     0
# 10388  zamistanpur_hyderabad       1.0          2         2        3     0
# 10391  zamistanpur_hyderabad       1.0          0         1        3     0
# 10392  zamistanpur_hyderabad       2.0          2         2        1     0
#
#        furnishingDesc  property_size  rent_amount  maintenance  rent_per_sqft
# 2                 0.0            680        10000            0      14.705882
# 4                 0.0            600         9500            0      15.833333
# 6                 0.5            500         8500            0      17.000000
# 9                 0.0            400         7000            0      17.500000
# 11                0.5            800        12000         1000      15.000000
# ...               ...            ...          ...          ...            ...
# 10384             0.5            450         7000            0      15.555556
# 10387             0.5            700        10500          500      15.000000
# 10388             0.0            500         8000            0      16.000000
# 10391             0.0            500         6000            0      12.000000
# 10392             0.5           1010        16000         1000      15.841584
#
# [5075 rows x 11 columns]

# %%
plt.hist(df7.rent_per_sqft,rwidth=0.85)
plt.xlabel('rent per sqft')
plt.ylabel('count')

plt.show()

# %%
df8= df7.drop('rent_per_sqft',axis=1)
df8.property_size.sort_values()
# Out:
# 8848     310
# 8847     310
# 3491     340
# 5987     340
# 3259     350
#         ...
# 6715    4000
# 3541    4000
# 9536    5000
# 6576    5500
# 7133    7000
# Name: property_size, Length: 5075, dtype: int64

# %%
df8.to_csv('data/cleaned_data.csv',index=False)

# %%
dummies= pd.get_dummies(df8.localityId)
dummies.head()
# Out:
#     adikmet_hyderabad  almasguda_hyderabad  amberpet_hyderabad  \
# 2                   1                    0                   0
# 4                   1                    0                   0
# 6                   1                    0                   0
# 9                   1                    0                   0
# 11                  1                    0                   0
#
#     ameerpet_hyderabad  attapur_hyderabad  badangpet_hyderabad  \
# 2                    0                  0                    0
# 4                    0                  0                    0
# 6                    0                  0                    0
# 9                    0                  0                    0
# 11                   0                  0                    0
#
#     badesahebguda_hyderabad  balakampet_hyderabad  balanagar_hyderabad  \
# 2                         0                     0                    0
# 4                         0                     0                    0
# 6                         0                     0                    0
# 9                         0                     0                    0
# 11                        0                     0                    0
#
#     balapur_hyderabad  ...  turkayamjal_hyderabad  uppal_hyderabad  \
# 2                   0  ...                      0                0
# 4                   0  ...                      0                0
# 6                   0  ...                      0                0
# 9                   0  ...                      0                0
# 11                  0  ...                      0                0
#
#     upparpally_hyderabad  venkat_nagar_colony_hyderabad  \
# 2                      0                              0
# 4                      0                              0
# 6                      0                              0
# 9                      0                              0
# 11                     0                              0
#
#     west_marredpally_hyderabad  whisper_valley_hyderabad  yapral_hyderabad  \
# 2                            0                         0                 0
# 4                            0                         0                 0
# 6                            0                         0                 0
# 9                            0                         0                 0
# 11                           0                         0                 0
#
#     yella_reddy_guda_hyderabad  yousufguda_hyderabad  zamistanpur_hyderabad
# 2                            0                     0                      0
# 4                            0                     0                      0
# 6                            0                     0                      0
# 9                            0                     0                      0
# 11                           0                     0                      0
#
# [5 rows x 145 columns]

# %%
df9= pd.concat([df8.drop('localityId',axis=1),dummies],axis=1)
df9
# Out:
#        type_bhk  balconies  bathroom  parking  lift  furnishingDesc  \
# 2           2.0          1         2        1     0             0.0
# 4           2.0          2         1        1     0             0.0
# 6           1.0          0         1        0     0             0.5
# 9           0.5          1         1        3     0             0.0
# 11          2.0          0         1        1     0             0.5
# ...         ...        ...       ...      ...   ...             ...
# 10384       1.0          1         1        1     0             0.5
# 10387       2.0          1         1        1     0             0.5
# 10388       1.0          2         2        3     0             0.0
# 10391       1.0          0         1        3     0             0.0
# 10392       2.0          2         2        1     0             0.5
#
#        property_size  rent_amount  maintenance  adikmet_hyderabad  ...  \
# 2                680        10000            0                  1  ...
# 4                600         9500            0                  1  ...
# 6                500         8500            0                  1  ...
# 9                400         7000            0                  1  ...
# 11               800        12000         1000                  1  ...
# ...              ...          ...          ...                ...  ...
# 10384            450         7000            0                  0  ...
# 10387            700        10500          500                  0  ...
# 10388            500         8000            0                  0  ...
# 10391            500         6000            0                  0  ...
# 10392           1010        16000         1000                  0  ...
#
#        turkayamjal_hyderabad  uppal_hyderabad  upparpally_hyderabad  \
# 2                          0                0                     0
# 4                          0                0                     0
# 6                          0                0                     0
# 9                          0                0                     0
# 11                         0                0                     0
# ...                      ...              ...                   ...
# 10384                      0                0                     0
# 10387                      0                0                     0
# 10388                      0                0                     0
# 10391                      0                0                     0
# 10392                      0                0                     0
#
#        venkat_nagar_colony_hyderabad  west_marredpally_hyderabad  \
# 2                                  0                           0
# 4                                  0                           0
# 6                                  0                           0
# 9                                  0                           0
# 11                                 0                           0
# ...                              ...                         ...
# 10384                              0                           0
# 10387                              0                           0
# 10388                              0                           0
# 10391                              0                           0
# 10392                              0                           0
#
#        whisper_valley_hyderabad  yapral_hyderabad  yella_reddy_guda_hyderabad  \
# 2                             0                 0                           0
# 4                             0                 0                           0
# 6                             0                 0                           0
# 9                             0                 0                           0
# 11                            0                 0                           0
# ...                         ...               ...                         ...
# 10384                         0                 0                           0
# 10387                         0                 0                           0
# 10388                         0                 0                           0
# 10391                         0                 0                           0
# 10392                         0                 0                           0
#
#        yousufguda_hyderabad  zamistanpur_hyderabad
# 2                         0                      0
# 4                         0                      0
# 6                         0                      0
# 9                         0                      0
# 11                        0                      0
# ...                     ...                    ...
# 10384                     0                      1
# 10387                     0                      1
# 10388                     0                      1
# 10391                     0                      1
# 10392                     0                      1
#
# [5075 rows x 154 columns]

# %%
df9.describe()
# Out:
#           type_bhk    balconies     bathroom      parking         lift  \
# count  5075.000000  5075.000000  5075.000000  5075.000000  5075.000000
# mean      1.731232     0.657143     1.706798     1.833498     0.246700
# std       0.794567     0.872366     0.737224     1.052458     0.431133
# min       0.500000     0.000000     1.000000     0.000000     0.000000
# 25%       1.000000     0.000000     1.000000     1.000000     0.000000
# 50%       2.000000     0.000000     2.000000     1.000000     0.000000
# 75%       2.000000     1.000000     2.000000     3.000000     0.000000
# max       5.000000     5.000000     6.000000     3.000000     1.000000
#
#        furnishingDesc  property_size    rent_amount  maintenance  \
# count     5075.000000    5075.000000    5075.000000  5075.000000
# mean         0.274483     932.582857   13906.285517   433.987783
# std          0.311596     477.457227    9284.554994   747.102893
# min          0.000000     310.000000    2500.000000     0.000000
# 25%          0.000000     550.000000    8000.000000     0.000000
# 50%          0.000000     850.000000   11000.000000     0.000000
# 75%          0.500000    1180.500000   17000.000000   600.000000
# max          1.000000    7000.000000  100000.000000  8500.000000
#
#        adikmet_hyderabad  ...  turkayamjal_hyderabad  uppal_hyderabad  \
# count        5075.000000  ...            5075.000000      5075.000000
# mean            0.004335  ...               0.001576         0.011034
# std             0.065704  ...               0.039676         0.104474
# min             0.000000  ...               0.000000         0.000000
# 25%             0.000000  ...               0.000000         0.000000
# 50%             0.000000  ...               0.000000         0.000000
# 75%             0.000000  ...               0.000000         0.000000
# max             1.000000  ...               1.000000         1.000000
#
#        upparpally_hyderabad  venkat_nagar_colony_hyderabad  \
# count           5075.000000                     5075.00000
# mean               0.004729                        0.00197
# std                0.068612                        0.04435
# min                0.000000                        0.00000
# 25%                0.000000                        0.00000
# 50%                0.000000                        0.00000
# 75%                0.000000                        0.00000
# max                1.000000                        1.00000
#
#        west_marredpally_hyderabad  whisper_valley_hyderabad  yapral_hyderabad  \
# count                 5075.000000               5075.000000       5075.000000
# mean                     0.003941                  0.003350          0.002365
# std                      0.062659                  0.057786          0.048574
# min                      0.000000                  0.000000          0.000000
# 25%                      0.000000                  0.000000          0.000000
# 50%                      0.000000                  0.000000          0.000000
# 75%                      0.000000                  0.000000          0.000000
# max                      1.000000                  1.000000          1.000000
#
#        yella_reddy_guda_hyderabad  yousufguda_hyderabad  zamistanpur_hyderabad
# count                 5075.000000           5075.000000            5075.000000
# mean                     0.004532              0.015369               0.006108
# std                      0.067174              0.123029               0.077925
# min                      0.000000              0.000000               0.000000
# 25%                      0.000000              0.000000               0.000000
# 50%                      0.000000              0.000000               0.000000
# 75%                      0.000000              0.000000               0.000000
# max                      1.000000              1.000000               1.000000
#
# [8 rows x 154 columns]

# %% [markdown]
# ## Model Building

# %%
X = df9.drop('rent_amount',axis=1)
y = df9.rent_amount

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Lasso Regression': Lasso(),
    'Ridge Regression': Ridge(),
    'Decision Tree Regressor': DecisionTreeRegressor(),
    'Random Forest Regressor': RandomForestRegressor(),
    'Gradient Boosting Regressor': GradientBoostingRegressor()
}

# %%
param_grids = {
    'Linear Regression': {},
    'Lasso Regression': {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]},
    'Ridge Regression': {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]},
    'Decision Tree Regressor': {'max_depth': [None, 5, 10], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]},
    'Random Forest Regressor': {'n_estimators': [50, 100, 150], 'max_depth': [None, 5, 10]},
    'Gradient Boosting Regressor': {'n_estimators': [50, 100, 150], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 4, 5]}
}

# %%
def train_and_tune_model(model, param_grid, X_train, y_train):
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='r2')
    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    return best_model

# %%
def predict_and_evaluate(model, X_test, y_test):
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    return r2, mae, mse, rmse

# %%
best_models = {}
model_scores = {}

for model_name, model in models.items():
    print(f'Training and tuning {model_name}...')
    param_grid = param_grids[model_name]
    best_model = train_and_tune_model(model, param_grid, X_train, y_train)
    best_models[model_name] = best_model
    r2, _, _, _ = predict_and_evaluate(best_model, X_test, y_test)
    model_scores[model_name] = r2
    print(f'{model_name} - R-squared: {r2:.4f}')
# Out:
# Training and tuning Linear Regression...
# Linear Regression - R-squared: 0.9020
# Training and tuning Lasso Regression...
# Lasso Regression - R-squared: 0.9020
# Training and tuning Ridge Regression...
# Ridge Regression - R-squared: 0.9030
# Training and tuning Decision Tree Regressor...
# Decision Tree Regressor - R-squared: 0.8319
# Training and tuning Random Forest Regressor...
# Random Forest Regressor - R-squared: 0.8901
# Training and tuning Gradient Boosting Regressor...
# Gradient Boosting Regressor - R-squared: 0.9043

# %%
def plot_model_scores(model_names, r2_scores):
    plt.figure(figsize=(10, 6))
    plt.bar(model_names, r2_scores)
    plt.xlabel('Model')
    plt.ylabel('R-squared Score')
    plt.title('Comparison of Model Scores')
    plt.ylim(0, 1)
    plt.xticks(rotation=30, ha='right')  # Adjust rotation angle and alignment
    plt.tight_layout()  # Ensure tight layout to prevent clipping
    plt.show()

# %%
# Plot model scores for comparison
model_names = list(models.keys())
r2_scores = [model_scores[name] for name in model_names]
plot_model_scores(model_names, r2_scores)

best_model_name = max(model_scores, key=model_scores.get)
best_model_for_deployment = best_models[best_model_name]

print(f'\nThe best model for deployment is: {best_model_name} with R-squared: {model_scores[best_model_name]:.4f}')
# Out:
# The best model for deployment is: Gradient Boosting Regressor with R-squared: 0.9043

# %%
from sklearn.linear_model import LinearRegression
Lr= LinearRegression()
Lr.fit(X_train,y_train)
Lr.score(X_test,y_test)
# Out:
# 0.9019578362996811

# %%
def predict_price(localityId, type_bhk, balconies, bathroom, parking, lift, furnishingDesc, property_size, maintenance):
    loc_index = np.where(X.columns == localityId)[0]
    
    if loc_index:
        loc_index = loc_index[0]
        x = np.zeros(len(X.columns))
        x[0] = type_bhk
        x[1] = balconies
        x[2] = bathroom
        x[3] = parking
        x[4] = lift
        x[5] = furnishingDesc
        x[6] = property_size
        x[7] = maintenance

        if loc_index >= 0:
            x[loc_index] = 1

        return best_model.predict([x])[0]
    else:
        return "LocalityId not found in training data."

# %%
predict_price('zamistanpur_hyderabad',5,5,4,3,1,1,5000,1000)
# Out:
# 66302.86423257983

# %%
import pickle
with open('hyd_house_rent_prices.pkl','wb') as f:
    pickle.dump(Lr,f)
